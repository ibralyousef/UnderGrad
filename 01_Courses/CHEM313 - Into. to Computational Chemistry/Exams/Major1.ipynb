# %%
from matplotlib import pyplot as plt
import numpy as np
angs = np.array([180, 165, 150, 135, 120, 105, 90, 75, 60])
enz = np.array([-74.844633642841, -74.856749915940, -74.886654542822, -74.921364565684, -74.949859106285, -74.964902268025, -74.961203167896, -74.934026517279 , -74.878577565723])
plt.plot(angs, enz, 'black')

plt.xlabel("Angles")
plt.ylabel("Energy")
plt.show()

# %%
plt.plot(angs, enz, 'black')

plt.xlabel("Angles")
plt.ylabel("Energy")
plt.axvline(x=105.020, color='r')
plt.show()
